# %%
import numpy as np

# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    5.0
# 4    NaN
# 5    6.0
# 6    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[us]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[us]
# C           float32
# D             int32
# E          category
# F               str
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  2.181584 -1.092441 -1.829978  0.461729
# 2013-01-02 -0.172833  0.325413  0.833112  0.097450
# 2013-01-03 -1.621515  1.921257  0.052538  0.138033
# 2013-01-04  1.139768  0.252806 -0.984610  1.643745
# 2013-01-05  0.661179  0.772980  0.842714  0.206045

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  1.139768  0.252806 -0.984610  1.643745
# 2013-01-05  0.661179  0.772980  0.842714  0.206045
# 2013-01-06 -0.515660  1.651614 -0.298425 -0.215968

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[us]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='str')

# %%
df.to_numpy()
# Out:
# array([[ 2.1815841 , -1.09244115, -1.82997802,  0.46172936],
#        [-0.1728325 ,  0.32541322,  0.83311177,  0.09744953],
#        [-1.62151502,  1.92125744,  0.05253846,  0.13803316],
#        [ 1.13976808,  0.25280566, -0.98460998,  1.6437453 ],
#        [ 0.66117934,  0.77298029,  0.84271367,  0.20604547],
#        [-0.51566019,  1.6516145 , -0.29842543, -0.21596825]])

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[us]
# C           float32
# D             int32
# E          category
# F               str
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.278754  0.638605 -0.230775  0.388506
# std    1.338238  1.089302  1.048312  0.652245
# min   -1.621515 -1.092441 -1.829978 -0.215968
# 25%   -0.429953  0.270958 -0.813064  0.107595
# 50%    0.244173  0.549197 -0.122943  0.172039
# 75%    1.020121  1.431956  0.637968  0.397808
# max    2.181584  1.921257  0.842714  1.643745

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    2.181584   -0.172833   -1.621515    1.139768    0.661179   -0.515660
# B   -1.092441    0.325413    1.921257    0.252806    0.772980    1.651614
# C   -1.829978    0.833112    0.052538   -0.984610    0.842714   -0.298425
# D    0.461729    0.097450    0.138033    1.643745    0.206045   -0.215968

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.461729 -1.829978 -1.092441  2.181584
# 2013-01-02  0.097450  0.833112  0.325413 -0.172833
# 2013-01-03  0.138033  0.052538  1.921257 -1.621515
# 2013-01-04  1.643745 -0.984610  0.252806  1.139768
# 2013-01-05  0.206045  0.842714  0.772980  0.661179
# 2013-01-06 -0.215968 -0.298425  1.651614 -0.515660

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-01  2.181584 -1.092441 -1.829978  0.461729
# 2013-01-04  1.139768  0.252806 -0.984610  1.643745
# 2013-01-02 -0.172833  0.325413  0.833112  0.097450
# 2013-01-05  0.661179  0.772980  0.842714  0.206045
# 2013-01-06 -0.515660  1.651614 -0.298425 -0.215968
# 2013-01-03 -1.621515  1.921257  0.052538  0.138033

# %%
df["A"]
# Out:
# 2013-01-01    2.181584
# 2013-01-02   -0.172833
# 2013-01-03   -1.621515
# 2013-01-04    1.139768
# 2013-01-05    0.661179
# 2013-01-06   -0.515660
# Freq: D, Name: A, dtype: float64

# %%
df[["B", "A"]]
# Out:
#                    B         A
# 2013-01-01 -1.092441  2.181584
# 2013-01-02  0.325413 -0.172833
# 2013-01-03  1.921257 -1.621515
# 2013-01-04  0.252806  1.139768
# 2013-01-05  0.772980  0.661179
# 2013-01-06  1.651614 -0.515660

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  2.181584 -1.092441 -1.829978  0.461729
# 2013-01-02 -0.172833  0.325413  0.833112  0.097450
# 2013-01-03 -1.621515  1.921257  0.052538  0.138033

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.172833  0.325413  0.833112  0.097450
# 2013-01-03 -1.621515  1.921257  0.052538  0.138033
# 2013-01-04  1.139768  0.252806 -0.984610  1.643745

# %%
df.loc[dates[0]]
# Out:
# A    2.181584
# B   -1.092441
# C   -1.829978
# D    0.461729
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  2.181584 -1.092441
# 2013-01-02 -0.172833  0.325413
# 2013-01-03 -1.621515  1.921257
# 2013-01-04  1.139768  0.252806
# 2013-01-05  0.661179  0.772980
# 2013-01-06 -0.515660  1.651614

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -0.172833  0.325413
# 2013-01-03 -1.621515  1.921257
# 2013-01-04  1.139768  0.252806

# %%
df.loc[dates[0], "A"]
# Out:
# np.float64(2.18158410473685)

# %%
df.at[dates[0], "A"]
# Out:
# np.float64(2.18158410473685)

# %%
df.iloc[3]
# Out:
# A    1.139768
# B    0.252806
# C   -0.984610
# D    1.643745
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  1.139768  0.252806
# 2013-01-05  0.661179  0.772980

# %%
df.iloc[[1,2,4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02 -0.172833  0.833112
# 2013-01-03 -1.621515  0.052538
# 2013-01-05  0.661179  0.842714

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.172833  0.325413  0.833112  0.097450
# 2013-01-03 -1.621515  1.921257  0.052538  0.138033

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -1.092441 -1.829978
# 2013-01-02  0.325413  0.833112
# 2013-01-03  1.921257  0.052538
# 2013-01-04  0.252806 -0.984610
# 2013-01-05  0.772980  0.842714
# 2013-01-06  1.651614 -0.298425

# %%
df.iloc[1,1]
# Out:
# np.float64(0.3254132169116814)

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  2.181584 -1.092441 -1.829978  0.461729
# 2013-01-04  1.139768  0.252806 -0.984610  1.643745
# 2013-01-05  0.661179  0.772980  0.842714  0.206045

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01  2.181584       NaN       NaN  0.461729
# 2013-01-02       NaN  0.325413  0.833112  0.097450
# 2013-01-03       NaN  1.921257  0.052538  0.138033
# 2013-01-04  1.139768  0.252806       NaN  1.643745
# 2013-01-05  0.661179  0.772980  0.842714  0.206045
# 2013-01-06       NaN  1.651614       NaN       NaN

# %%
df2 = df.copy()

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three"]

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  2.181584 -1.092441 -1.829978  0.461729    one
# 2013-01-02 -0.172833  0.325413  0.833112  0.097450    one
# 2013-01-03 -1.621515  1.921257  0.052538  0.138033    two
# 2013-01-04  1.139768  0.252806 -0.984610  1.643745  three
# 2013-01-05  0.661179  0.772980  0.842714  0.206045   four
# 2013-01-06 -0.515660  1.651614 -0.298425 -0.215968  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.621515  1.921257  0.052538  0.138033   two
# 2013-01-05  0.661179  0.772980  0.842714  0.206045  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df[" F"] = s1

# %%
df.at[dates[0], "A"] =0

# %%
df.iat[0,1] = 0

# %%
df.loc[:,"D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -1.829978  5.0  NaN
# 2013-01-02 -0.172833  0.325413  0.833112  5.0  1.0
# 2013-01-03 -1.621515  1.921257  0.052538  5.0  2.0
# 2013-01-04  1.139768  0.252806 -0.984610  5.0  3.0
# 2013-01-05  0.661179  0.772980  0.842714  5.0  4.0
# 2013-01-06 -0.515660  1.651614 -0.298425  5.0  5.0

# %%
df2 = df.copy()

# %%
df2[df2>0] = -df2

# %%
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -1.829978 -5.0  NaN
# 2013-01-02 -0.172833 -0.325413 -0.833112 -5.0 -1.0
# 2013-01-03 -1.621515 -1.921257 -0.052538 -5.0 -2.0
# 2013-01-04 -1.139768 -0.252806 -0.984610 -5.0 -3.0
# 2013-01-05 -0.661179 -0.772980 -0.842714 -5.0 -4.0
# 2013-01-06 -0.515660 -1.651614 -0.298425 -5.0 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

# %%
df1.loc[dates[0]:dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -1.829978  5.0  NaN  1.0
# 2013-01-02 -0.172833  0.325413  0.833112  5.0  1.0  1.0
# 2013-01-03 -1.621515  1.921257  0.052538  5.0  2.0  NaN
# 2013-01-04  1.139768  0.252806 -0.984610  5.0  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E
# 2013-01-02 -0.172833  0.325413  0.833112  5.0  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -1.829978  5.0  5.0  1.0
# 2013-01-02 -0.172833  0.325413  0.833112  5.0  1.0  1.0
# 2013-01-03 -1.621515  1.921257  0.052538  5.0  2.0  5.0
# 2013-01-04  1.139768  0.252806 -0.984610  5.0  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A    -0.084843
# B     0.820679
# C    -0.230775
# D     5.000000
#  F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    0.792505
# 2013-01-02    1.397138
# 2013-01-03    1.470456
# 2013-01-04    1.681593
# 2013-01-05    2.255375
# 2013-01-06    2.167506
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 2, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
df.agg(lambda x : np.mean(x) * 5.6)
# Out:
# A     -0.475123
# B      4.595800
# C     -1.292340
# D     28.000000
#  F    16.800000
# dtype: float64

# %%
pd.Series(np.random.randint(0, 7, size=10))
# Out:
# 0    6
# 1    5
# 2    3
# 3    5
# 4    1
# 5    6
# 6    4
# 7    1
# 8    0
# 9    6
# dtype: int32

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    2.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.subtract(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -2.621515  0.921257 -0.947462  4.0  1.0
# 2013-01-04 -0.860232 -1.747194 -2.984610  3.0  1.0
# 2013-01-05 -4.338821 -4.227020 -4.157286  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.agg(lambda x: np.mean(x)* 5.6)
# Out:
# A     -0.475123
# B      4.595800
# C     -1.292340
# D     28.000000
#  F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x* 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000 -185.193776  506.0    NaN
# 2013-01-02  -17.490649   32.931818   84.310911  506.0  101.2
# 2013-01-03 -164.097320  194.431253    5.316892  506.0  202.4
# 2013-01-04  115.344529   25.583933  -99.642530  506.0  303.6
# 2013-01-05   66.911349   78.225605   85.282623  506.0  404.8
# 2013-01-06  -52.184811  167.143387  -30.200654  506.0  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    3
# 1    2
# 2    5
# 3    6
# 4    2
# 5    4
# 6    3
# 7    5
# 8    2
# 9    4
# dtype: int32

# %%
s.value_counts()
# Out:
# 2    3
# 3    2
# 5    2
# 4    2
# 6    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: str

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0 -2.211914  0.322273  0.223254 -1.313153
# 1  0.275702  0.828768 -1.815238  0.797070
# 2  1.012473 -0.350647 -0.929261  2.347621
# 3 -0.038299 -2.520768  1.312680  0.118050
# 4 -0.604068  0.902522  0.667844  0.080299
# 5  0.598686 -1.445999 -0.712171 -0.341398
# 6  1.180440  0.139856  0.044910  1.526352
# 7  1.858151  1.262996 -0.752265  0.645024
# 8 -0.418359 -0.103617  0.895166  0.661627
# 9  1.286237 -0.924162 -0.055790  0.552824

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -2.211914  0.322273  0.223254 -1.313153
# 1  0.275702  0.828768 -1.815238  0.797070
# 2  1.012473 -0.350647 -0.929261  2.347621
# 3 -0.038299 -2.520768  1.312680  0.118050
# 4 -0.604068  0.902522  0.667844  0.080299
# 5  0.598686 -1.445999 -0.712171 -0.341398
# 6  1.180440  0.139856  0.044910  1.526352
# 7  1.858151  1.262996 -0.752265  0.645024
# 8 -0.418359 -0.103617  0.895166  0.661627
# 9  1.286237 -0.924162 -0.055790  0.552824

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one  0.138369  0.278157
# 1  bar    one  0.454154 -1.024510
# 2  foo    two -1.304086 -1.439167
# 3  bar  three -0.803367  1.025312
# 4  foo    two  0.304161  2.451034
# 5  bar    two -0.042574 -1.135865
# 6  foo    one -0.476478 -1.318342
# 7  foo  three  1.577996 -0.537792

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -0.391787 -1.135063
# foo  0.239963 -0.566110

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.454154 -1.024510
#     three -0.803367  1.025312
#     two   -0.042574 -1.135865
# foo one   -0.338108 -1.040184
#     three  1.577996 -0.537792
#     two   -0.999925  1.011867

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -1.500836  0.882871
#       two     0.908612 -0.946815
# baz   one     0.288527 -0.306915
#       two    -1.401017  0.322242

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -1.500836
#                B    0.882871
#        two     A    0.908612
#                B   -0.946815
# baz    one     A    0.288527
#                B   -0.306915
#        two     A   -1.401017
#                B    0.322242
# dtype: float64

# %%
stacked.unstack
# Out:
# <bound method Series.unstack of first  second
# bar    one     A   -1.500836
#                B    0.882871
#        two     A    0.908612
#                B   -0.946815
# baz    one     A    0.288527
#                B   -0.306915
#        two     A   -1.401017
#                B    0.322242
# dtype: float64>

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -1.500836  0.908612
#       B  0.882871 -0.946815
# baz   A  0.288527 -1.401017
#       B -0.306915  0.322242

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -1.500836  0.288527
#        B  0.882871 -0.306915
# two    A  0.908612 -1.401017
#        B -0.946815  0.322242

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.341953  1.130990
# 1     one  B  foo  0.952098 -0.439955
# 2     two  C  foo -0.621833  0.223334
# 3   three  A  bar -2.171228  0.760779
# 4     one  B  bar  0.574729 -0.291830
# 5     one  C  bar -1.785860 -1.600434
# 6     two  A  foo -0.738405 -0.567883
# 7   three  B  foo -0.479605  0.740924
# 8     one  C  foo  0.262225 -0.252447
# 9     one  A  bar -0.680196 -0.383335
# 10    two  B  bar  0.604413  0.368163
# 11  three  C  bar -0.381330  0.286557

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -0.680196 -1.341953
#       B  0.574729  0.952098
#       C -1.785860  0.262225
# three A -2.171228       NaN
#       B       NaN -0.479605
#       C -0.381330       NaN
# two   A       NaN -0.738405
#       B  0.604413       NaN
#       C       NaN -0.621833

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    24011
# Freq: 5min, dtype: int32

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -0.578438
# 2012-03-07    0.607266
# 2012-03-08   -0.397809
# 2012-03-09   -0.808607
# 2012-03-10   -0.039825
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.578438
# 2012-03-07 00:00:00+00:00    0.607266
# 2012-03-08 00:00:00+00:00   -0.397809
# 2012-03-09 00:00:00+00:00   -0.808607
# 2012-03-10 00:00:00+00:00   -0.039825
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.578438
# 2012-03-06 19:00:00-05:00    0.607266
# 2012-03-07 19:00:00-05:00   -0.397809
# 2012-03-08 19:00:00-05:00   -0.808607
# 2012-03-09 19:00:00-05:00   -0.039825
# dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[us]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[us]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, str): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, str): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)


df = df.cumsum()

plt.figure();

df.plot();

plt.legend(loc='best');

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  1  4  1  0
# 1           1  2  4  3  1  4
# 2           2  3  0  3  4  4
# 3           3  4  0  2  1  3
# 4           4  2  3  4  2  0
# 5           5  1  4  4  3  1
# 6           6  1  0  3  2  4
# 7           7  0  4  0  4  3
# 8           8  1  3  4  2  0
# 9           9  2  4  0  2  0

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")
